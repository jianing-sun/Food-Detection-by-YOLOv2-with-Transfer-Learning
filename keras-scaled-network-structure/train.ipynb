# %%
import argparse
import json
import os

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.optimizers import Adam

from callbacks import CustomModelCheckpoint, CustomTensorBoard
from generator import BatchGenerator
from utils.multi_gpu_model import multi_gpu_model
from utils.utils import normalize, evaluate, makedirs, parse_annotation
from scaled_mobilenet import create_scaled_mobilenet_model, dummy_loss

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def create_train_valid_set(
        train_annot_folder,
        train_image_folder,
        valid_annot_folder,
        valid_image_folder,
        labels,
):
    # parse annotations for all images
    all_images = []
    all_seen_labels = []
    for i in range(0, len(labels)):
        image_path = train_image_folder + str(i + 1) + '/'
        annot_path = train_annot_folder + str(i + 1) + '/' + 'annotations_new/'

        train_ints, seen_labels = parse_annotation(annot_path, image_path, labels)

        all_images.extend(train_ints)
        for seen_label, counts in seen_labels.items():
            if seen_label not in all_seen_labels:
                all_seen_labels.append(seen_label)

    # parse annotations of the validation set, if any, otherwise split the training set
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_annotation(valid_annot_folder, valid_image_folder, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")
        train_valid_split = int(0.8 * len(all_images))
        np.random.seed(0)
        np.random.shuffle(all_images)
        np.random.seed()

        valid_ints = all_images[train_valid_split:]
        train_ints = all_images[:train_valid_split]

    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(all_seen_labels))
        if len(overlap_labels) == len(labels) == len(all_seen_labels):
            print('All 100 categories appeared.\n')

    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])
    print('Maximum box number per image: ' + str(max_box_per_image) + '\n')

    return train_ints, valid_ints, labels, max_box_per_image

# %%
def create_callbacks(saved_weights_name, tensorboard_logs, model_to_save):
    makedirs(tensorboard_logs)

    early_stop = EarlyStopping(
        monitor='loss',
        min_delta=0.01,
        patience=5,
        mode='min',
        verbose=1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save=model_to_save,
        filepath=saved_weights_name,  # + '{epoch:02d}.h5',
        monitor='loss',
        verbose=1,
        save_best_only=True,
        mode='min',
        period=1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor='loss',
        factor=0.1,
        patience=2,
        verbose=1,
        mode='min',
        epsilon=0.01,
        cooldown=0,
        min_lr=0
    )
    tensorboard = CustomTensorBoard(
        log_dir=tensorboard_logs,
        write_graph=True,
        write_images=True,
    )
    return [early_stop, checkpoint, reduce_on_plateau, tensorboard]

# %%
def create_model(
        nb_class,
        anchors,
        max_box_per_image,
        max_grid, batch_size,
        warmup_batches,
        ignore_thresh,
        multi_gpu,
        saved_weights_name,
        lr,
        grid_scales,
        obj_scale,
        noobj_scale,
        xywh_scale,
        class_scale
):
    if multi_gpu > 1:
        with tf.device('/cpu:0'):
            template_model, infer_model = create_scaled_mobilenet_model(
                nb_class=nb_class,
                anchors=anchors,
                max_box_per_image=max_box_per_image,
                max_grid=max_grid,
                batch_size=batch_size // multi_gpu,
                warmup_batches=warmup_batches,
                ignore_thresh=ignore_thresh,
                grid_scales=grid_scales,
                obj_scale=obj_scale,
                noobj_scale=noobj_scale,
                xywh_scale=xywh_scale,
                class_scale=class_scale
            )
    else:
        template_model, infer_model = create_scaled_mobilenet_model(
            nb_class=nb_class,
            anchors=anchors,
            max_box_per_image=max_box_per_image,
            max_grid=max_grid,
            batch_size=batch_size,
            warmup_batches=warmup_batches,
            ignore_thresh=ignore_thresh,
            grid_scales=grid_scales,
            obj_scale=obj_scale,
            noobj_scale=noobj_scale,
            xywh_scale=xywh_scale,
            class_scale=class_scale
        )

    # load the pretrained weight if exists, otherwise load the backend weight only
    # if os.path.exists(saved_weights_name):
    #     print("\nLoading pretrained weights.\n")
    #     template_model.load_weights(saved_weights_name)
    # else:
    #     template_model.load_weights("backend.h5", by_name=True)

    if multi_gpu > 1:
        train_model = multi_gpu_model(template_model, gpus=multi_gpu)
    else:
        train_model = template_model

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)

    return train_model, infer_model

# %%
def read_category():
    category = []
    with open('/Volumes/JS/UECFOOD100_JS/category.txt', 'r') as file:
        for i, line in enumerate(file):
            if i > 0:
                line = line.rstrip('\n')
                line = line.split('\t')
                category.append(line[1])
    return category

# %%
def _main():
    config_path = './config.json'
    LABELS = read_category()

    with open(config_path) as config_buffer:
        config = json.loads(config_buffer.read())

    ''' Parse annotations '''
    config['model']['labels'] = LABELS
    train_ints, valid_ints, labels, max_box_per_image = create_train_valid_set(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['valid']['valid_annot_folder'],
        config['valid']['valid_image_folder'],
        config['model']['labels']
    )

    ''' Create generators '''
    # check if images are normal after BatchGenerator
    batches = BatchGenerator(instances=np.append(train_ints, valid_ints),
                             anchors=config['model']['anchors'],
                             labels=labels,
                             downsample=32,
                             max_box_per_image=max_box_per_image,
                             batch_size=config['train']['batch_size'],
                             shuffle=False,
                             jitter=False)
    img = batches[0][0][0][5]
    # plt.imshow(img.astype('uint8'))

    train_generator = BatchGenerator(
        instances=train_ints,
        anchors=config['model']['anchors'],
        labels=labels,
        downsample=32,  # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image=max_box_per_image,
        batch_size=config['train']['batch_size'],
        # min_net_size=config['model']['min_input_size'],
        # max_net_size=config['model']['max_input_size'],
        shuffle=True,
        jitter=True,  # add 10% noise for each image for training
        norm=normalize
    )

    img = train_generator[0][0][0][5]
    # plt.imshow(img.astype('float'))

    valid_generator = BatchGenerator(
        instances=valid_ints,
        anchors=config['model']['anchors'],
        labels=labels,
        downsample=32,  # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image=max_box_per_image,
        batch_size=config['train']['batch_size'],
        # min_net_size=config['model']['min_input_size'],
        # max_net_size=config['model']['max_input_size'],
        shuffle=True,
        jitter=False,
        norm=normalize
    )

    ''' Create the model '''
    if os.path.exists(config['train']['saved_weights_name']):
        config['train']['warmup_epochs'] = 0
    warmup_batches = config['train']['warmup_epochs'] * (config['train']['train_times'] * len(train_generator))

    os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']
    multi_gpu = len(config['train']['gpus'].split(','))

    train_model, infer_model = create_model(
        nb_class=len(labels),
        anchors=config['model']['anchors'],
        max_box_per_image=max_box_per_image,
        max_grid=[config['model']['max_input_size'], config['model']['max_input_size']],
        batch_size=config['train']['batch_size'],
        warmup_batches=warmup_batches,
        ignore_thresh=config['train']['ignore_thresh'],
        multi_gpu=multi_gpu,
        saved_weights_name=config['train']['saved_weights_name'],
        lr=config['train']['learning_rate'],
        grid_scales=config['train']['grid_scales'],
        obj_scale=config['train']['obj_scale'],
        noobj_scale=config['train']['noobj_scale'],
        xywh_scale=config['train']['xywh_scale'],
        class_scale=config['train']['class_scale'],
    )

    print('\ntrain_model: \n')
    print(train_model.summary())
    print('\ninfer_model: \n')
    print(infer_model.summary())

    ''' Kick off the training '''
    callbacks = create_callbacks(config['train']['saved_weights_name'], config['train']['tensorboard_dir'], infer_model)
    train_model.fit_generator(
        generator=train_generator,
        steps_per_epoch=len(train_generator),   # * config['train']['train_times'],
        epochs=config['train']['nb_epochs'] + config['train']['warmup_epochs'],
        verbose=2 if config['train']['debug'] else 1,
        callbacks=callbacks,
        # workers=4,
        max_queue_size=8
    )

    # make a GPU version of infer_model for evaluation
    if multi_gpu > 1:
        infer_model = load_model(config['train']['saved_weights_name'])

    ''' Evaluate the result '''
    # compute mAP for all the classes
    average_precisions = evaluate(infer_model, valid_generator)

    # print the score
    for label, average_precision in average_precisions.items():
        print(labels[label] + ': {:.4f}'.format(average_precision))
    print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))

# %%
_main()
# Out:
# valid_annot_folder not exists. Spliting the trainining set.
# All 100 categories appeared.
#
# Maximum box number per image: 12
#
#
# train_model:
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropad (ZeroPadding2D)   (None, 226, 226, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_zeropad[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu6 (Activation)        (None, 112, 112, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_2 (ZeroPadding2D (None, 114, 114, 32) 0           conv1_relu6[0][0]
# __________________________________________________________________________________________________
# convdw_2 (DepthwiseConv2D)      (None, 112, 112, 32) 288         convdw_zeropad_2[0][0]
# __________________________________________________________________________________________________
# convdw_bn_2 (BatchNormalization (None, 112, 112, 32) 128         convdw_2[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_2 (Activation)     (None, 112, 112, 32) 0           convdw_bn_2[0][0]
# __________________________________________________________________________________________________
# convpw_2 (Conv2D)               (None, 112, 112, 64) 2048        convdw_relu6_2[0][0]
# __________________________________________________________________________________________________
# convpw_bn_2 (BatchNormalization (None, 112, 112, 64) 256         convpw_2[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_2 (Activation)     (None, 112, 112, 64) 0           convpw_bn_2[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_4 (ZeroPadding2D (None, 114, 114, 64) 0           convpw_relu6_2[0][0]
# __________________________________________________________________________________________________
# convdw_4 (DepthwiseConv2D)      (None, 56, 56, 64)   576         convdw_zeropad_4[0][0]
# __________________________________________________________________________________________________
# convdw_bn_4 (BatchNormalization (None, 56, 56, 64)   256         convdw_4[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_4 (Activation)     (None, 56, 56, 64)   0           convdw_bn_4[0][0]
# __________________________________________________________________________________________________
# convpw_4 (Conv2D)               (None, 56, 56, 128)  8192        convdw_relu6_4[0][0]
# __________________________________________________________________________________________________
# convpw_bn_4 (BatchNormalization (None, 56, 56, 128)  512         convpw_4[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_4 (Activation)     (None, 56, 56, 128)  0           convpw_bn_4[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_6 (ZeroPadding2D (None, 58, 58, 128)  0           convpw_relu6_4[0][0]
# __________________________________________________________________________________________________
# convdw_6 (DepthwiseConv2D)      (None, 56, 56, 128)  1152        convdw_zeropad_6[0][0]
# __________________________________________________________________________________________________
# convdw_bn_6 (BatchNormalization (None, 56, 56, 128)  512         convdw_6[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_6 (Activation)     (None, 56, 56, 128)  0           convdw_bn_6[0][0]
# __________________________________________________________________________________________________
# convpw_6 (Conv2D)               (None, 56, 56, 128)  16384       convdw_relu6_6[0][0]
# __________________________________________________________________________________________________
# convpw_bn_6 (BatchNormalization (None, 56, 56, 128)  512         convpw_6[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_6 (Activation)     (None, 56, 56, 128)  0           convpw_bn_6[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_8 (ZeroPadding2D (None, 58, 58, 128)  0           convpw_relu6_6[0][0]
# __________________________________________________________________________________________________
# convdw_8 (DepthwiseConv2D)      (None, 28, 28, 128)  1152        convdw_zeropad_8[0][0]
# __________________________________________________________________________________________________
# convdw_bn_8 (BatchNormalization (None, 28, 28, 128)  512         convdw_8[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_8 (Activation)     (None, 28, 28, 128)  0           convdw_bn_8[0][0]
# __________________________________________________________________________________________________
# convpw_8 (Conv2D)               (None, 28, 28, 256)  32768       convdw_relu6_8[0][0]
# __________________________________________________________________________________________________
# convpw_bn_8 (BatchNormalization (None, 28, 28, 256)  1024        convpw_8[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_8 (Activation)     (None, 28, 28, 256)  0           convpw_bn_8[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_10 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_8[0][0]
# __________________________________________________________________________________________________
# convdw_10 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        convdw_zeropad_10[0][0]
# __________________________________________________________________________________________________
# convdw_bn_10 (BatchNormalizatio (None, 28, 28, 256)  1024        convdw_10[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_10 (Activation)    (None, 28, 28, 256)  0           convdw_bn_10[0][0]
# __________________________________________________________________________________________________
# convpw_10 (Conv2D)              (None, 28, 28, 256)  65536       convdw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convpw_bn_10 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_10[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_10 (Activation)    (None, 28, 28, 256)  0           convpw_bn_10[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_12 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convdw_12 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        convdw_zeropad_12[0][0]
# __________________________________________________________________________________________________
# convdw_bn_12 (BatchNormalizatio (None, 14, 14, 256)  1024        convdw_12[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_12 (Activation)    (None, 14, 14, 256)  0           convdw_bn_12[0][0]
# __________________________________________________________________________________________________
# convpw_12 (Conv2D)              (None, 14, 14, 512)  131072      convdw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convpw_bn_12 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_12[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_12 (Activation)    (None, 14, 14, 512)  0           convpw_bn_12[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_14 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convdw_14 (DepthwiseConv2D)     (None, 7, 7, 512)    4608        convdw_zeropad_14[0][0]
# __________________________________________________________________________________________________
# convdw_bn_14 (BatchNormalizatio (None, 7, 7, 512)    2048        convdw_14[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_14 (Activation)    (None, 7, 7, 512)    0           convdw_bn_14[0][0]
# __________________________________________________________________________________________________
# convpw_14 (Conv2D)              (None, 7, 7, 512)    262144      convdw_relu6_14[0][0]
# __________________________________________________________________________________________________
# convpw_bn_14 (BatchNormalizatio (None, 7, 7, 512)    2048        convpw_14[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_14 (Activation)    (None, 7, 7, 512)    0           convpw_bn_14[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_19 (ZeroPadding2 (None, 9, 9, 512)    0           convpw_relu6_14[0][0]
# __________________________________________________________________________________________________
# convdw_19 (DepthwiseConv2D)     (None, 7, 7, 512)    4608        convdw_zeropad_19[0][0]
# __________________________________________________________________________________________________
# convdw_bn_19 (BatchNormalizatio (None, 7, 7, 512)    2048        convdw_19[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_19 (Activation)    (None, 7, 7, 512)    0           convdw_bn_19[0][0]
# __________________________________________________________________________________________________
# convpw_19 (Conv2D)              (None, 7, 7, 512)    262144      convdw_relu6_19[0][0]
# __________________________________________________________________________________________________
# convpw_bn_19 (BatchNormalizatio (None, 7, 7, 512)    2048        convpw_19[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_19 (Activation)    (None, 7, 7, 512)    0           convpw_bn_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 512)  0           convpw_relu6_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1024) 0           up_sampling2d_1[0][0]
#                                                                  convpw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_22 (ZeroPadding2 (None, 16, 16, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# convdw_22 (DepthwiseConv2D)     (None, 14, 14, 1024) 9216        convdw_zeropad_22[0][0]
# __________________________________________________________________________________________________
# convdw_bn_22 (BatchNormalizatio (None, 14, 14, 1024) 4096        convdw_22[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_22 (Activation)    (None, 14, 14, 1024) 0           convdw_bn_22[0][0]
# __________________________________________________________________________________________________
# convpw_22 (Conv2D)              (None, 14, 14, 512)  524288      convdw_relu6_22[0][0]
# __________________________________________________________________________________________________
# convpw_bn_22 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_22[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_22 (Activation)    (None, 14, 14, 512)  0           convpw_bn_22[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_24 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_22[0][0]
# __________________________________________________________________________________________________
# convdw_24 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        convdw_zeropad_24[0][0]
# __________________________________________________________________________________________________
# convdw_bn_24 (BatchNormalizatio (None, 14, 14, 512)  2048        convdw_24[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_24 (Activation)    (None, 14, 14, 512)  0           convdw_bn_24[0][0]
# __________________________________________________________________________________________________
# convpw_24 (Conv2D)              (None, 14, 14, 512)  262144      convdw_relu6_24[0][0]
# __________________________________________________________________________________________________
# convpw_bn_24 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_24[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_24 (Activation)    (None, 14, 14, 512)  0           convpw_bn_24[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_26 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_24[0][0]
# __________________________________________________________________________________________________
# convdw_26 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        convdw_zeropad_26[0][0]
# __________________________________________________________________________________________________
# convdw_bn_26 (BatchNormalizatio (None, 14, 14, 512)  2048        convdw_26[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_26 (Activation)    (None, 14, 14, 512)  0           convdw_bn_26[0][0]
# __________________________________________________________________________________________________
# convpw_26 (Conv2D)              (None, 14, 14, 512)  262144      convdw_relu6_26[0][0]
# __________________________________________________________________________________________________
# convpw_bn_26 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_26[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_26 (Activation)    (None, 14, 14, 512)  0           convpw_bn_26[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_31 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_26[0][0]
# __________________________________________________________________________________________________
# convdw_31 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        convdw_zeropad_31[0][0]
# __________________________________________________________________________________________________
# convdw_bn_31 (BatchNormalizatio (None, 14, 14, 512)  2048        convdw_31[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_31 (Activation)    (None, 14, 14, 512)  0           convdw_bn_31[0][0]
# __________________________________________________________________________________________________
# convpw_31 (Conv2D)              (None, 14, 14, 512)  262144      convdw_relu6_31[0][0]
# __________________________________________________________________________________________________
# convpw_bn_31 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_31[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_31 (Activation)    (None, 14, 14, 512)  0           convpw_bn_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           convpw_relu6_31[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  convpw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_34 (ZeroPadding2 (None, 30, 30, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# convdw_34 (DepthwiseConv2D)     (None, 28, 28, 768)  6912        convdw_zeropad_34[0][0]
# __________________________________________________________________________________________________
# convdw_bn_34 (BatchNormalizatio (None, 28, 28, 768)  3072        convdw_34[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_34 (Activation)    (None, 28, 28, 768)  0           convdw_bn_34[0][0]
# __________________________________________________________________________________________________
# convpw_34 (Conv2D)              (None, 28, 28, 512)  393216      convdw_relu6_34[0][0]
# __________________________________________________________________________________________________
# convpw_bn_34 (BatchNormalizatio (None, 28, 28, 512)  2048        convpw_34[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_34 (Activation)    (None, 28, 28, 512)  0           convpw_bn_34[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_36 (ZeroPadding2 (None, 30, 30, 512)  0           convpw_relu6_34[0][0]
# __________________________________________________________________________________________________
# convdw_36 (DepthwiseConv2D)     (None, 28, 28, 512)  4608        convdw_zeropad_36[0][0]
# __________________________________________________________________________________________________
# convdw_bn_36 (BatchNormalizatio (None, 28, 28, 512)  2048        convdw_36[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_36 (Activation)    (None, 28, 28, 512)  0           convdw_bn_36[0][0]
# __________________________________________________________________________________________________
# convpw_36 (Conv2D)              (None, 28, 28, 512)  262144      convdw_relu6_36[0][0]
# __________________________________________________________________________________________________
# convpw_bn_36 (BatchNormalizatio (None, 28, 28, 512)  2048        convpw_36[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_36 (Activation)    (None, 28, 28, 512)  0           convpw_bn_36[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_38 (ZeroPadding2 (None, 30, 30, 512)  0           convpw_relu6_36[0][0]
# __________________________________________________________________________________________________
# convdw_38 (DepthwiseConv2D)     (None, 28, 28, 512)  4608        convdw_zeropad_38[0][0]
# __________________________________________________________________________________________________
# convdw_bn_38 (BatchNormalizatio (None, 28, 28, 512)  2048        convdw_38[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_38 (Activation)    (None, 28, 28, 512)  0           convdw_bn_38[0][0]
# __________________________________________________________________________________________________
# convpw_38 (Conv2D)              (None, 28, 28, 256)  131072      convdw_relu6_38[0][0]
# __________________________________________________________________________________________________
# convpw_bn_38 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_38[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_38 (Activation)    (None, 28, 28, 256)  0           convpw_bn_38[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_40 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_38[0][0]
# __________________________________________________________________________________________________
# convdw_40 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        convdw_zeropad_40[0][0]
# __________________________________________________________________________________________________
# convdw_bn_40 (BatchNormalizatio (None, 28, 28, 256)  1024        convdw_40[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_40 (Activation)    (None, 28, 28, 256)  0           convdw_bn_40[0][0]
# __________________________________________________________________________________________________
# convpw_40 (Conv2D)              (None, 28, 28, 256)  65536       convdw_relu6_40[0][0]
# __________________________________________________________________________________________________
# convpw_bn_40 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_40[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_40 (Activation)    (None, 28, 28, 256)  0           convpw_bn_40[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_16 (DepthwiseConv2 (None, 7, 7, 512)    4608        convpw_relu6_14[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_28 (DepthwiseConv2 (None, 14, 14, 512)  4608        convpw_relu6_26[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_38 (DepthwiseConv2 (None, 28, 28, 256)  2304        convpw_relu6_40[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_16 (BatchNormaliz (None, 7, 7, 512)    2048        yolo_dw_conv_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_28 (BatchNormaliz (None, 14, 14, 512)  2048        yolo_dw_conv_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_38 (BatchNormaliz (None, 28, 28, 256)  1024        yolo_dw_conv_38[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_16 (Activation)   (None, 7, 7, 512)    0           yolo_dw_bnorm_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_28 (Activation)   (None, 14, 14, 512)  0           yolo_dw_bnorm_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_38 (Activation)   (None, 28, 28, 256)  0           yolo_dw_bnorm_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_16 (Conv2D)        (None, 7, 7, 512)    262144      yolo_dw_relu6_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_28 (Conv2D)        (None, 14, 14, 256)  131072      yolo_dw_relu6_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_38 (Conv2D)        (None, 28, 28, 128)  32768       yolo_dw_relu6_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_16 (BatchNormalizati (None, 7, 7, 512)    2048        yolo_pw_conv_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_28 (BatchNormalizati (None, 14, 14, 256)  1024        yolo_pw_conv_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_38 (BatchNormalizati (None, 28, 28, 128)  512         yolo_pw_conv_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_16 (Activation)   (None, 7, 7, 512)    0           yolo_pw_bn_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_28 (Activation)   (None, 14, 14, 256)  0           yolo_pw_bn_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_38 (Activation)   (None, 28, 28, 128)  0           yolo_pw_bn_38[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_17 (DepthwiseConv2 (None, 7, 7, 512)    512         yolo_pw_relu6_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_29 (DepthwiseConv2 (None, 14, 14, 256)  256         yolo_pw_relu6_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_39 (DepthwiseConv2 (None, 28, 28, 128)  128         yolo_pw_relu6_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_17 (Conv2D)        (None, 7, 7, 315)    161280      yolo_dw_conv_17[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_29 (Conv2D)        (None, 14, 14, 315)  80640       yolo_dw_conv_29[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_39 (Conv2D)        (None, 28, 28, 315)  40320       yolo_dw_conv_39[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_17 (BatchNormalizati (None, 7, 7, 315)    1260        yolo_pw_conv_17[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1, 1, 1, 12,  0
# __________________________________________________________________________________________________
# yolo_pw_bn_29 (BatchNormalizati (None, 14, 14, 315)  1260        yolo_pw_conv_29[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# yolo_pw_bn_39 (BatchNormalizati (None, 28, 28, 315)  1260        yolo_pw_conv_39[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# yolo_layer_1 (YoloLayer)        (None, 1)            0           input_1[0][0]
#                                                                  yolo_pw_bn_17[0][0]
#                                                                  input_3[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# yolo_layer_2 (YoloLayer)        (None, 1)            0           input_1[0][0]
#                                                                  yolo_pw_bn_29[0][0]
#                                                                  input_4[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# yolo_layer_3 (YoloLayer)        (None, 1)            0           input_1[0][0]
#                                                                  yolo_pw_bn_39[0][0]
#                                                                  input_5[0][0]
#                                                                  input_2[0][0]
# ==================================================================================================
# Total params: 3,785,348
# Trainable params: 3,754,146
# Non-trainable params: 31,202
# __________________________________________________________________________________________________
# None
#
# infer_model:
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropad (ZeroPadding2D)   (None, 226, 226, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_zeropad[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu6 (Activation)        (None, 112, 112, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_2 (ZeroPadding2D (None, 114, 114, 32) 0           conv1_relu6[0][0]
# __________________________________________________________________________________________________
# convdw_2 (DepthwiseConv2D)      (None, 112, 112, 32) 288         convdw_zeropad_2[0][0]
# __________________________________________________________________________________________________
# convdw_bn_2 (BatchNormalization (None, 112, 112, 32) 128         convdw_2[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_2 (Activation)     (None, 112, 112, 32) 0           convdw_bn_2[0][0]
# __________________________________________________________________________________________________
# convpw_2 (Conv2D)               (None, 112, 112, 64) 2048        convdw_relu6_2[0][0]
# __________________________________________________________________________________________________
# convpw_bn_2 (BatchNormalization (None, 112, 112, 64) 256         convpw_2[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_2 (Activation)     (None, 112, 112, 64) 0           convpw_bn_2[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_4 (ZeroPadding2D (None, 114, 114, 64) 0           convpw_relu6_2[0][0]
# __________________________________________________________________________________________________
# convdw_4 (DepthwiseConv2D)      (None, 56, 56, 64)   576         convdw_zeropad_4[0][0]
# __________________________________________________________________________________________________
# convdw_bn_4 (BatchNormalization (None, 56, 56, 64)   256         convdw_4[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_4 (Activation)     (None, 56, 56, 64)   0           convdw_bn_4[0][0]
# __________________________________________________________________________________________________
# convpw_4 (Conv2D)               (None, 56, 56, 128)  8192        convdw_relu6_4[0][0]
# __________________________________________________________________________________________________
# convpw_bn_4 (BatchNormalization (None, 56, 56, 128)  512         convpw_4[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_4 (Activation)     (None, 56, 56, 128)  0           convpw_bn_4[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_6 (ZeroPadding2D (None, 58, 58, 128)  0           convpw_relu6_4[0][0]
# __________________________________________________________________________________________________
# convdw_6 (DepthwiseConv2D)      (None, 56, 56, 128)  1152        convdw_zeropad_6[0][0]
# __________________________________________________________________________________________________
# convdw_bn_6 (BatchNormalization (None, 56, 56, 128)  512         convdw_6[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_6 (Activation)     (None, 56, 56, 128)  0           convdw_bn_6[0][0]
# __________________________________________________________________________________________________
# convpw_6 (Conv2D)               (None, 56, 56, 128)  16384       convdw_relu6_6[0][0]
# __________________________________________________________________________________________________
# convpw_bn_6 (BatchNormalization (None, 56, 56, 128)  512         convpw_6[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_6 (Activation)     (None, 56, 56, 128)  0           convpw_bn_6[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_8 (ZeroPadding2D (None, 58, 58, 128)  0           convpw_relu6_6[0][0]
# __________________________________________________________________________________________________
# convdw_8 (DepthwiseConv2D)      (None, 28, 28, 128)  1152        convdw_zeropad_8[0][0]
# __________________________________________________________________________________________________
# convdw_bn_8 (BatchNormalization (None, 28, 28, 128)  512         convdw_8[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_8 (Activation)     (None, 28, 28, 128)  0           convdw_bn_8[0][0]
# __________________________________________________________________________________________________
# convpw_8 (Conv2D)               (None, 28, 28, 256)  32768       convdw_relu6_8[0][0]
# __________________________________________________________________________________________________
# convpw_bn_8 (BatchNormalization (None, 28, 28, 256)  1024        convpw_8[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_8 (Activation)     (None, 28, 28, 256)  0           convpw_bn_8[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_10 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_8[0][0]
# __________________________________________________________________________________________________
# convdw_10 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        convdw_zeropad_10[0][0]
# __________________________________________________________________________________________________
# convdw_bn_10 (BatchNormalizatio (None, 28, 28, 256)  1024        convdw_10[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_10 (Activation)    (None, 28, 28, 256)  0           convdw_bn_10[0][0]
# __________________________________________________________________________________________________
# convpw_10 (Conv2D)              (None, 28, 28, 256)  65536       convdw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convpw_bn_10 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_10[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_10 (Activation)    (None, 28, 28, 256)  0           convpw_bn_10[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_12 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convdw_12 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        convdw_zeropad_12[0][0]
# __________________________________________________________________________________________________
# convdw_bn_12 (BatchNormalizatio (None, 14, 14, 256)  1024        convdw_12[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_12 (Activation)    (None, 14, 14, 256)  0           convdw_bn_12[0][0]
# __________________________________________________________________________________________________
# convpw_12 (Conv2D)              (None, 14, 14, 512)  131072      convdw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convpw_bn_12 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_12[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_12 (Activation)    (None, 14, 14, 512)  0           convpw_bn_12[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_14 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convdw_14 (DepthwiseConv2D)     (None, 7, 7, 512)    4608        convdw_zeropad_14[0][0]
# __________________________________________________________________________________________________
# convdw_bn_14 (BatchNormalizatio (None, 7, 7, 512)    2048        convdw_14[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_14 (Activation)    (None, 7, 7, 512)    0           convdw_bn_14[0][0]
# __________________________________________________________________________________________________
# convpw_14 (Conv2D)              (None, 7, 7, 512)    262144      convdw_relu6_14[0][0]
# __________________________________________________________________________________________________
# convpw_bn_14 (BatchNormalizatio (None, 7, 7, 512)    2048        convpw_14[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_14 (Activation)    (None, 7, 7, 512)    0           convpw_bn_14[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_19 (ZeroPadding2 (None, 9, 9, 512)    0           convpw_relu6_14[0][0]
# __________________________________________________________________________________________________
# convdw_19 (DepthwiseConv2D)     (None, 7, 7, 512)    4608        convdw_zeropad_19[0][0]
# __________________________________________________________________________________________________
# convdw_bn_19 (BatchNormalizatio (None, 7, 7, 512)    2048        convdw_19[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_19 (Activation)    (None, 7, 7, 512)    0           convdw_bn_19[0][0]
# __________________________________________________________________________________________________
# convpw_19 (Conv2D)              (None, 7, 7, 512)    262144      convdw_relu6_19[0][0]
# __________________________________________________________________________________________________
# convpw_bn_19 (BatchNormalizatio (None, 7, 7, 512)    2048        convpw_19[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_19 (Activation)    (None, 7, 7, 512)    0           convpw_bn_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 512)  0           convpw_relu6_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1024) 0           up_sampling2d_1[0][0]
#                                                                  convpw_relu6_12[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_22 (ZeroPadding2 (None, 16, 16, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# convdw_22 (DepthwiseConv2D)     (None, 14, 14, 1024) 9216        convdw_zeropad_22[0][0]
# __________________________________________________________________________________________________
# convdw_bn_22 (BatchNormalizatio (None, 14, 14, 1024) 4096        convdw_22[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_22 (Activation)    (None, 14, 14, 1024) 0           convdw_bn_22[0][0]
# __________________________________________________________________________________________________
# convpw_22 (Conv2D)              (None, 14, 14, 512)  524288      convdw_relu6_22[0][0]
# __________________________________________________________________________________________________
# convpw_bn_22 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_22[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_22 (Activation)    (None, 14, 14, 512)  0           convpw_bn_22[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_24 (ZeroPadding2 (None, 16, 16, 512)  0           convpw_relu6_22[0][0]
# __________________________________________________________________________________________________
# convdw_24 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        convdw_zeropad_24[0][0]
# __________________________________________________________________________________________________
# convdw_bn_24 (BatchNormalizatio (None, 14, 14, 512)  2048        convdw_24[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_24 (Activation)    (None, 14, 14, 512)  0           convdw_bn_24[0][0]
# __________________________________________________________________________________________________
# convpw_24 (Conv2D)              (None, 14, 14, 512)  262144      convdw_relu6_24[0][0]
# __________________________________________________________________________________________________
# convpw_bn_24 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_24[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_24 (Activation)    (None, 14, 14, 512)  0           convpw_bn_24[0][0]
# ...
# __________________________________________________________________________________________________
# convpw_bn_31 (BatchNormalizatio (None, 14, 14, 512)  2048        convpw_31[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_31 (Activation)    (None, 14, 14, 512)  0           convpw_bn_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           convpw_relu6_31[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  convpw_relu6_10[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_34 (ZeroPadding2 (None, 30, 30, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# convdw_34 (DepthwiseConv2D)     (None, 28, 28, 768)  6912        convdw_zeropad_34[0][0]
# __________________________________________________________________________________________________
# convdw_bn_34 (BatchNormalizatio (None, 28, 28, 768)  3072        convdw_34[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_34 (Activation)    (None, 28, 28, 768)  0           convdw_bn_34[0][0]
# __________________________________________________________________________________________________
# convpw_34 (Conv2D)              (None, 28, 28, 512)  393216      convdw_relu6_34[0][0]
# __________________________________________________________________________________________________
# convpw_bn_34 (BatchNormalizatio (None, 28, 28, 512)  2048        convpw_34[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_34 (Activation)    (None, 28, 28, 512)  0           convpw_bn_34[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_36 (ZeroPadding2 (None, 30, 30, 512)  0           convpw_relu6_34[0][0]
# __________________________________________________________________________________________________
# convdw_36 (DepthwiseConv2D)     (None, 28, 28, 512)  4608        convdw_zeropad_36[0][0]
# __________________________________________________________________________________________________
# convdw_bn_36 (BatchNormalizatio (None, 28, 28, 512)  2048        convdw_36[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_36 (Activation)    (None, 28, 28, 512)  0           convdw_bn_36[0][0]
# __________________________________________________________________________________________________
# convpw_36 (Conv2D)              (None, 28, 28, 512)  262144      convdw_relu6_36[0][0]
# __________________________________________________________________________________________________
# convpw_bn_36 (BatchNormalizatio (None, 28, 28, 512)  2048        convpw_36[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_36 (Activation)    (None, 28, 28, 512)  0           convpw_bn_36[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_38 (ZeroPadding2 (None, 30, 30, 512)  0           convpw_relu6_36[0][0]
# __________________________________________________________________________________________________
# convdw_38 (DepthwiseConv2D)     (None, 28, 28, 512)  4608        convdw_zeropad_38[0][0]
# __________________________________________________________________________________________________
# convdw_bn_38 (BatchNormalizatio (None, 28, 28, 512)  2048        convdw_38[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_38 (Activation)    (None, 28, 28, 512)  0           convdw_bn_38[0][0]
# __________________________________________________________________________________________________
# convpw_38 (Conv2D)              (None, 28, 28, 256)  131072      convdw_relu6_38[0][0]
# __________________________________________________________________________________________________
# convpw_bn_38 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_38[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_38 (Activation)    (None, 28, 28, 256)  0           convpw_bn_38[0][0]
# __________________________________________________________________________________________________
# convdw_zeropad_40 (ZeroPadding2 (None, 30, 30, 256)  0           convpw_relu6_38[0][0]
# __________________________________________________________________________________________________
# convdw_40 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        convdw_zeropad_40[0][0]
# __________________________________________________________________________________________________
# convdw_bn_40 (BatchNormalizatio (None, 28, 28, 256)  1024        convdw_40[0][0]
# __________________________________________________________________________________________________
# convdw_relu6_40 (Activation)    (None, 28, 28, 256)  0           convdw_bn_40[0][0]
# __________________________________________________________________________________________________
# convpw_40 (Conv2D)              (None, 28, 28, 256)  65536       convdw_relu6_40[0][0]
# __________________________________________________________________________________________________
# convpw_bn_40 (BatchNormalizatio (None, 28, 28, 256)  1024        convpw_40[0][0]
# __________________________________________________________________________________________________
# convpw_relu6_40 (Activation)    (None, 28, 28, 256)  0           convpw_bn_40[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_16 (DepthwiseConv2 (None, 7, 7, 512)    4608        convpw_relu6_14[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_28 (DepthwiseConv2 (None, 14, 14, 512)  4608        convpw_relu6_26[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_38 (DepthwiseConv2 (None, 28, 28, 256)  2304        convpw_relu6_40[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_16 (BatchNormaliz (None, 7, 7, 512)    2048        yolo_dw_conv_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_28 (BatchNormaliz (None, 14, 14, 512)  2048        yolo_dw_conv_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_bnorm_38 (BatchNormaliz (None, 28, 28, 256)  1024        yolo_dw_conv_38[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_16 (Activation)   (None, 7, 7, 512)    0           yolo_dw_bnorm_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_28 (Activation)   (None, 14, 14, 512)  0           yolo_dw_bnorm_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_relu6_38 (Activation)   (None, 28, 28, 256)  0           yolo_dw_bnorm_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_16 (Conv2D)        (None, 7, 7, 512)    262144      yolo_dw_relu6_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_28 (Conv2D)        (None, 14, 14, 256)  131072      yolo_dw_relu6_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_38 (Conv2D)        (None, 28, 28, 128)  32768       yolo_dw_relu6_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_16 (BatchNormalizati (None, 7, 7, 512)    2048        yolo_pw_conv_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_28 (BatchNormalizati (None, 14, 14, 256)  1024        yolo_pw_conv_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_38 (BatchNormalizati (None, 28, 28, 128)  512         yolo_pw_conv_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_16 (Activation)   (None, 7, 7, 512)    0           yolo_pw_bn_16[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_28 (Activation)   (None, 14, 14, 256)  0           yolo_pw_bn_28[0][0]
# __________________________________________________________________________________________________
# yolo_pw_relu6_38 (Activation)   (None, 28, 28, 128)  0           yolo_pw_bn_38[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_17 (DepthwiseConv2 (None, 7, 7, 512)    512         yolo_pw_relu6_16[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_29 (DepthwiseConv2 (None, 14, 14, 256)  256         yolo_pw_relu6_28[0][0]
# __________________________________________________________________________________________________
# yolo_dw_conv_39 (DepthwiseConv2 (None, 28, 28, 128)  128         yolo_pw_relu6_38[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_17 (Conv2D)        (None, 7, 7, 315)    161280      yolo_dw_conv_17[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_29 (Conv2D)        (None, 14, 14, 315)  80640       yolo_dw_conv_29[0][0]
# __________________________________________________________________________________________________
# yolo_pw_conv_39 (Conv2D)        (None, 28, 28, 315)  40320       yolo_dw_conv_39[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_17 (BatchNormalizati (None, 7, 7, 315)    1260        yolo_pw_conv_17[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_29 (BatchNormalizati (None, 14, 14, 315)  1260        yolo_pw_conv_29[0][0]
# __________________________________________________________________________________________________
# yolo_pw_bn_39 (BatchNormalizati (None, 28, 28, 315)  1260        yolo_pw_conv_39[0][0]
# ==================================================================================================
# Total params: 3,785,348
# Trainable params: 3,754,146
# Non-trainable params: 31,202
# __________________________________________________________________________________________________
# None
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/callbacks.py:999: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Epoch 1/103
#   1/718 [..............................] - ETA: 7:53:55 - loss: 735.9209 - yolo_layer_1_loss: 81.5597 - yolo_layer_2_loss: 190.7400 - yolo_layer_3_loss: 463.6212
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a2d50cfcb460> in <module>()
# ----> 1 _main()
#
# <ipython-input-6-7a6f7656b339> in _main()
#     100         callbacks=callbacks,
#     101         # workers=4,
# --> 102         max_queue_size=8
#     103     )
#     104
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424             use_multiprocessing=use_multiprocessing,
#    1425             shuffle=shuffle,
# -> 1426             initial_epoch=initial_epoch)
#    1427
#    1428     @interfaces.legacy_generator_methods_support
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     189                 outs = model.train_on_batch(x, y,
#     190                                             sample_weight=sample_weight,
# --> 191                                             class_weight=class_weight)
#     192
#     193                 if not isinstance(outs, list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
